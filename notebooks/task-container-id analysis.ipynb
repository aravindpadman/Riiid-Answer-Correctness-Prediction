# %%
from dask.distributed import Client
import dask.dataframe as dd
import dask

import pandas as pd
import numpy as np

# ploting
import seaborn as sns
import matplotlib.pyplot as plt

# %%
client = Client()
client
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 57720 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:57721' processes=4 threads=4, memory=8.59 GB>

# %%
dtypes={
       'row_id': 'int32',
       'timestamp': 'int64', 
       'user_id': 'int32',
       'content_id': 'int16',
       'content_type_id': 'int8',
       'task_container_id': 'int16',
       'user_answer': 'int8', 
       'answered_correctly': 'int8',
       'prior_question_elapsed_time': 'float32', 
       'prior_question_had_explanation': 'bool',
   }

train = dd.read_csv("./data/train.csv", delimiter=',', low_memory=False)
questions = pd.read_csv("./data/questions.csv",)
lectures = pd.read_csv("./data/lectures.csv",)

questions['content_type_id'] = 0

# %%
train.user_id.max().compute()
# Out:
# 2147482888

# %%
train.dtypes
# Out:
# row_id                              int64
# timestamp                           int64
# user_id                             int64
# content_id                          int64
# content_type_id                     int64
# task_container_id                   int64
# user_answer                         int64
# answered_correctly                  int64
# prior_question_elapsed_time       float64
# prior_question_had_explanation     object
# dtype: object

# %% [markdown]
# ### User Level Analysis
#
# instead of analyzing the entire dataset at a time, here i am focusing on a single user data to better understand the how data is generated and the features

# %%
user_interaction_count = train.sample(frac=0.1).groupby("user_id").row_id.count().compute()

# %%
train_user = train.loc[train.user_id == 801103753].compute()

# %%
train_user.isna().sum(axis=0)
# Out:
# row_id                              0
# timestamp                           0
# user_id                             0
# content_id                          0
# content_type_id                     0
# task_container_id                   0
# user_answer                         0
# answered_correctly                  0
# prior_question_elapsed_time       309
# prior_question_had_explanation      1
# dtype: int64

# %%
train_user[train_user.prior_question_elapsed_time.isna()]
# Out:
#           row_id    timestamp    user_id  content_id  content_type_id  \
# 398131  37497771            0  801103753        4886                0
# 398172  37497812    148074210  801103753        3153                1
# 398199  37497839    205559895  801103753       21411                1
# 398219  37497859    385005893  801103753        8976                1
# 398243  37497883    512863699  801103753        5752                1
# ...          ...          ...        ...         ...              ...
# 415425  37515065  27800679566  801103753        4705                1
# 415592  37515232  27896097838  801103753       19147                1
# 415656  37515296  27936740093  801103753       24402                1
# 415911  37515551  28137140378  801103753       15722                1
# 415974  37515614  28324738435  801103753       10382                1
#
#         task_container_id  user_answer  answered_correctly  \
# 398131                  0            1                   0
# 398172                 42           -1                  -1
# 398199                 69           -1                  -1
# 398219                 77           -1                  -1
# 398243                113           -1                  -1
# ...                   ...          ...                 ...
# 415425               9536           -1                  -1
# 415592               9636           -1                  -1
# 415656               9684           -1                  -1
# 415911               9881           -1                  -1
# 415974               9937           -1                  -1
#
#         prior_question_elapsed_time prior_question_had_explanation
# 398131                          NaN                            NaN
# 398172                          NaN                          False
# 398199                          NaN                          False
# 398219                          NaN                          False
# 398243                          NaN                          False
# ...                             ...                            ...
# 415425                          NaN                          False
# 415592                          NaN                          False
# 415656                          NaN                          False
# 415911                          NaN                          False
# 415974                          NaN                          False
#
# [309 rows x 10 columns]

# %%
train_user.groupby(train_user.content_type_id). \
apply(lambda x: x['prior_question_elapsed_time'].isna().sum()). \
to_frame().rename({0:'prior_question_elapsed_time_NaNs_count'}, axis=1)
# Out:
#                  prior_question_elapsed_time_NaNs_count
# content_type_id
# 0                                                     1
# 1                                                   308

# %%
questions['content_type_id'] = 0

master_data = pd.merge(left=train_user[train_user.content_type_id == 0], 
                       right=questions, 
                       left_on=["content_id", "content_type_id"],
                       right_on=["question_id","content_type_id"],
                       how="left",
                      validate="m:1")

assert master_data.shape[0] == train_user[train_user.content_type_id == 0].shape[0]

# %%
master_data.isna().sum()
# Out:
# row_id                            0
# timestamp                         0
# user_id                           0
# content_id                        0
# content_type_id                   0
# task_container_id                 0
# user_answer                       0
# answered_correctly                0
# prior_question_elapsed_time       1
# prior_question_had_explanation    1
# question_id                       0
# bundle_id                         0
# correct_answer                    0
# part                              0
# tags                              0
# dtype: int64

# %% [markdown]
# ### Repeated Questions

# %%
df = master_data.groupby(master_data.question_id). \
agg({'row_id': ['count'], 'bundle_id': 'max',})

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.rename({'row_id_count': 'count', "bundle_id": 'question_bundle_id'}, axis=1).sort_values("count", ascending=False)
# Out:
#              count  bundle_id_max
# question_id
# 3348             9           3348
# 3349             9           3348
# 3350             9           3348
# 853              8            853
# 1756             8           1754
# ...            ...            ...
# 8762             1           8762
# 8763             1           8763
# 8764             1           8764
# 8766             1           8766
# 13520            1          13520
#
# [8977 rows x 2 columns]

# %%
master_data[master_data.question_id == 3348]
# Out:
#         row_id   timestamp    user_id  content_id  content_type_id  \
# 2447  37500328  3947698087  801103753        3348                0
# 5010  37502968  6119074538  801103753        3348                0
# 5038  37502996  6156802197  801103753        3348                0
# 5129  37503089  6233008928  801103753        3348                0
# 5167  37503128  6282655073  801103753        3348                0
# 5169  37503130  6282687298  801103753        3348                0
# 7712  37505696  9095340064  801103753        3348                0
# 7798  37505783  9136362894  801103753        3348                0
# 7943  37505928  9408109001  801103753        3348                0
#
#       task_container_id  user_answer  answered_correctly  \
# 2447               1648            1                   0
# 5010               3077            1                   0
# 5038               3090            0                   1
# 5129               3149            0                   1
# 5167               3171            0                   1
# 5169               3178            0                   1
# 7712               4738            1                   0
# 7798               4783            0                   1
# 7943               4840            0                   1
#
#       prior_question_elapsed_time prior_question_had_explanation  question_id  \
# 2447                      30000.0                           True         3348
# 5010                      30666.0                           True         3348
# 5038                      28333.0                           True         3348
# 5129                      10000.0                           True         3348
# 5167                      21000.0                           True         3348
# 5169                       4333.0                           True         3348
# 7712                      24666.0                           True         3348
# 7798                      24666.0                           True         3348
# 7943                      23000.0                           True         3348
#
#       bundle_id  correct_answer  part       tags
# 2447       3348               0     4  106 67 81
# 5010       3348               0     4  106 67 81
# 5038       3348               0     4  106 67 81
# 5129       3348               0     4  106 67 81
# 5167       3348               0     4  106 67 81
# 5169       3348               0     4  106 67 81
# 7712       3348               0     4  106 67 81
# 7798       3348               0     4  106 67 81
# 7943       3348               0     4  106 67 81

# %%
not_repeated_questions = master_data.sort_values("timestamp").drop_duplicates(['question_id'], keep='first')

# %%
not_repeated_questions
# Out:
#          row_id    timestamp    user_id  content_id  content_type_id  \
# 0      37497771            0  801103753        4886                0
# 1      37497772        21186  801103753        4032                0
# 2      37497773        55030  801103753        5927                0
# 3      37497774        81839  801103753        4754                0
# 4      37497775       103346  801103753        6336                0
# ...         ...          ...        ...         ...              ...
# 17603  37515682  28340412348  801103753        9548                0
# 17604  37515683  28340635545  801103753       13507                0
# 17605  37515684  28340706852  801103753        9203                0
# 17606  37515685  28340784904  801103753        9819                0
# 17608  37515687  28341066725  801103753        8873                0
#
#        task_container_id  user_answer  answered_correctly  \
# 0                      0            1                   0
# 1                      1            3                   0
# 2                      2            1                   1
# 3                      3            2                   1
# 4                      4            1                   0
# ...                  ...          ...                 ...
# 17603               9994            2                   1
# 17604               9995            0                   1
# 17605               9996            2                   1
# 17606               9997            0                   0
# 17608               9998            0                   1
#
#        prior_question_elapsed_time prior_question_had_explanation  \
# 0                              NaN                            NaN
# 1                         249000.0                          False
# 2                          18000.0                          False
# 3                          31000.0                          False
# 4                          24000.0                          False
# ...                            ...                            ...
# 17603                      44000.0                           True
# 17604                      36000.0                           True
# 17605                     136000.0                           True
# 17606                      35000.0                           True
# 17608                      17000.0                           True
#
#        question_id  bundle_id  correct_answer  part tags
# 0             4886       4886               3     5    8
# 1             4032       4032               1     5  173
# 2             5927       5927               1     5   89
# 3             4754       4754               2     5   53
# 4             6336       6336               0     5   53
# ...            ...        ...             ...   ...  ...
# 17603         9548       9548               2     5   73
# 17604        13507      13507               0     5   79
# 17605         9203       9203               2     5   96
# 17606         9819       9819               2     5    1
# 17608         8873       8873               0     5   73
#
# [8977 rows x 15 columns]

# %%
repeated_questions = master_data.loc[~master_data.index.isin(not_repeated_questions.index)]

# %%
repeated_questions[repeated_questions.question_id == 1398]
# Out:
#         row_id    timestamp    user_id  content_id  content_type_id  \
# 67    37497840    295274091  801103753        1398                0
# 87    37497861    385039564  801103753        1398                0
# 584   37498395   1235919526  801103753        1398                0
# 9618  37507619  11384875424  801103753        1398                0
#
#       task_container_id  user_answer  answered_correctly  \
# 67                   70            0                   1
# 87                   90            0                   1
# 584                 577            0                   1
# 9618               5651            0                   1
#
#       prior_question_elapsed_time prior_question_had_explanation  question_id  \
# 67                        19000.0                           True         1398
# 87                         8000.0                           True         1398
# 584                       12000.0                           True         1398
# 9618                      26000.0                           True         1398
#
#       bundle_id  correct_answer  part              tags
# 67         1398               0     2  62 155 163 38 81
# 87         1398               0     2  62 155 163 38 81
# 584        1398               0     2  62 155 163 38 81
# 9618       1398               0     2  62 155 163 38 81

# %%
not_repeated_questions.answered_correctly.mean()
# Out:
# 0.6805168764620697

# %%
repeated_questions.answered_correctly.mean()
# Out:
# 0.7633225208526413

# %%
repeated_vs_non_repeated = train.loc[1, ['row_id', 'timestamp',]].compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-8365e4ea6156> in <module>
# ----> 1 repeated_vs_non_repeated = train.loc[1, ['row_id', 'timestamp',]].compute()
#
# /opt/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# /opt/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2680                     should_rejoin = False
#    2681             try:
# -> 2682                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2683             finally:
#    2684                 for f in futures.values():
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1974             else:
#    1975                 local_worker = None
# -> 1976             return self.sync(
#    1977                 self._gather,
#    1978                 futures,
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     829             return future
#     830         else:
# --> 831             return sync(
#     832                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     833             )
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     334     else:
#     335         while not e.is_set():
# --> 336             e.wait(10)
#     337     if error[0]:
#     338         typ, exc, tb = error[0]
#
# /opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# /opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
train = dd.read_csv("./data/train.csv",
                    usecols=['row_id', 'user_id', 'timestamp', 
                             'content_id', 'content_type_id', 
                             'task_container_id', 'answered_correctly', ],)

# %%
train[train.content_type_id == 0].merge(questions[['question_id', 'bundle_id', 'content_type_id']], left_on=['content_id', 'content_type_id'],
           right_on = ['question_id', 'content_type_id'], how='left',). \
           groupby(['user_id', 'question_id']).agg({'row_id': ['count'], 'bundle_id': 'max',}). \
           rename(columns={'row_id_count': 'count', "bundle_id": 'question_bundle_id'},). \
            to_csv("./tmp/question_count_*.csv")
# Out:
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# <ipython-input-7-68363dc3306e> in <module>
# ----> 1 train[train.content_type_id == 0].merge(questions[['question_id', 'bundle_id', 'content_type_id']], left_on=['content_id', 'content_type_id'],
#       2            right_on = ['question_id', 'content_type_id'], how='left',). \
#       3            groupby(['user_id', 'question_id']).agg({'row_id': ['count'], 'bundle_id': 'max',}). \
#       4            rename(columns={'row_id_count': 'count', "bundle_id": 'question_bundle_id'},). \
#       5             to_csv("./tmp/question_count_*.csv")
#
# /opt/anaconda3/lib/python3.8/site-packages/dask/dataframe/core.py in to_csv(self, filename, **kwargs)
#    1406         from .io import to_csv
#    1407
# -> 1408         return to_csv(self, filename, **kwargs)
#    1409
#    1410     def to_sql(
#
# /opt/anaconda3/lib/python3.8/site-packages/dask/dataframe/io/csv.py in to_csv(df, filename, single_file, encoding, mode, name_function, compression, compute, scheduler, storage_options, header_first_partition_only, compute_kwargs, **kwargs)
#     890             compute_kwargs["scheduler"] = scheduler
#     891
# --> 892         delayed(values).compute(**compute_kwargs)
#     893         return [f.path for f in files]
#     894     else:
#
# /opt/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# /opt/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2680                     should_rejoin = False
#    2681             try:
# -> 2682                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2683             finally:
#    2684                 for f in futures.values():
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1974             else:
#    1975                 local_worker = None
# -> 1976             return self.sync(
#    1977                 self._gather,
#    1978                 futures,
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     829             return future
#     830         else:
# --> 831             return sync(
#     832                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     833             )
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     337     if error[0]:
#     338         typ, exc, tb = error[0]
# --> 339         raise exc.with_traceback(tb)
#     340     else:
#     341         return result[0]
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/utils.py in f()
#     321             if callback_timeout is not None:
#     322                 future = asyncio.wait_for(future, callback_timeout)
# --> 323             result[0] = yield future
#     324         except Exception as exc:
#     325             error[0] = sys.exc_info()
#
# /opt/anaconda3/lib/python3.8/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# /opt/anaconda3/lib/python3.8/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1839                             exc = CancelledError(key)
#    1840                         else:
# -> 1841                             raise exception.with_traceback(traceback)
#    1842                         raise exc
#    1843                     if errors == "skip":
#
# KilledWorker: ("('aggregate-combine-23c1edfaf941862812ad78f97ad4f1fa', 2, 0, 0)", <Worker 'tcp://127.0.0.1:57727', name: 0, memory: 0, processing: 1>)

# %%
import os
os.mkdir("tmp")
